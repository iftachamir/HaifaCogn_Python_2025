# %% [markdown]
# # Lesson 1: Introduction to Python – Variables, Numbers, and Basic Operations

# %% [markdown]
# ## Getting Started: Python & Jupyter Notebooks
# This is a *Jupyter Notebook*. It's used to share, describe, and run code interactively. Cells can be either markdown (text) or code.

# %%
# Example
import time

for letter in "HI EVERYONE":
    print(letter, end="")
    time.sleep(.15)

# %% [markdown]
# Jupyter Notebooks are especially useful for data analysis and scientific programming. You can have visualizations output from your code appearing inside the notebook.

# %%
import matplotlib.pyplot as plt
import numpy as np

def simulate_covid_and_lockdown(init_num, baseR, days_num):

    people = [init_num] 
    
    for i, days in enumerate(range(1, days_num)):
        
        if people[i] > 20_000:
            baseR = .9
        
        R = np.random.normal(baseR, .15, 1)
        init_num = init_num * R
        people = people + [int(init_num)]

    days = list(range(days_num))
    plt.plot(days, people, '-o')
    plt.title('Number of infected by day, lockdown initiated after 20,000 infected')
    plt.xlabel('# Days since ' + str(init_num) + ' persons infected')
    plt.ylabel('# of people infected')
    plt.show()  

    #test run    
simulate_covid_and_lockdown(10,1.3,42)

# %% [markdown]
# ## REPL and the Python Interpreter
#
# Python is an interpreted language, which means that code is executed line-by-line by an interpreter. This differs from compiled languages, where the entire program is translated into machine language before execution.
#
# Python provides an interactive environment called the **REPL (Read-Evaluate-Print Loop)**, which executes your commands immediately. This environment is especially useful for experimenting with short snippets of code and for quick testing.
#
# **How the REPL works:**
#
# - **Read**: Python reads the input command you type.
# - **Evaluate**: Python evaluates (executes) your command.
# - **Print**: Python prints the result or any output produced.
# - **Loop**: Python returns to the prompt, awaiting the next command.
#
# You can use this notebook as an interactive environment, similar to a REPL, by running small bits of code in separate cells.

# %%
print('Hello, World!')

# %%
# Demonstration of REPL-like behavior:
x = 10
y = 5
x + y  # Python evaluates this and prints the result immediately below
# Out:
# 15

# %%
print(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 print(x, y)
#
# NameError: name 'x' is not defined

# %% [markdown]
# ## Errors and Debugging
#
# Encountering errors is a normal and informative part of programming. Errors help you identify and correct issues in your code. Here are the three main types of errors you'll commonly encounter in Python:
#
# ### Syntax Errors
# Syntax errors occur when Python cannot interpret your code because it violates Python's grammar rules. Python will show an error message and indicate where the problem occurred.

# %%
# Syntax error
print('Hello World)
# Out:
#   File "C:\Users\iftac\AppData\Local\Temp\ipykernel_2160\2993569306.py", line 2
#     print('Hello World)
#                        ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# ### Runtime Errors
# Runtime errors occur during the execution of the program. The syntax is correct, but Python encounters an unexpected condition and cannot continue running your code.

# %%
# Runtime error example: uncomment and run this code to see the error.
print(1 / 0)  # Division by zero
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2160\3936714131.py in <module>
#       1 # Runtime error example: uncomment and run this code to see the error.
# ----> 2 print(1 / 0)  # Division by zero
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Debugging - Logic Errors
# Logic errors are the most subtle type. Your code runs without any explicit error messages, but it doesn't produce the expected outcome because the underlying logic is incorrect. Meaning Python is "correctly" doing what it's supposed to do - it is the programmer who has overlooked some issue(s).

# %%
# Logic error example:
x = 5
print(f'The square of {x} is:', x + x)  # Incorrect logic; should be x * x
# Out:
# The square of 5 is: 10

# %% [markdown]
# (I'll explain what f'' is when we learn `string`)

# %% [markdown]
# #### Printing variable **name** and **value**

# %%
y = 10
z = 'hello'

# There is a "shorthand" for printing a variable's name and its value together
print(f"{x=}", f"{y=}", f"{z=}")
# Out:
# x=5 y=10 z='hello'

# %% [markdown]
# ### Error line

# %%
# Compute the area of a right-angled triangle
a = 10
b = 20

result1 = a + b / 2
print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2160\1235914189.py in <module>
#       4
#       5 result1 = a + b / 2
# ----> 6 print(result)
#
# NameError: name 'result' is not defined

# %% [markdown]
# #### Exercise
# Correct the above code. Place your code below and run it.

# %%
# Enter corrected code here
...

# %% [markdown]
# ## Variables and Assignments
# Variables store values. Assignments are made using `=`. Clear examples below:

# %%
print(123)   # Not a variable

# %%
age = 30
first_name = 'Alice'

print(age, name)

# %%
x = 1 + 2 + 3 / 2

# %%
# What's the value of x?
print(x)
x

# %%
# Multiple assignment
x, y, z = 1, 2, 3
print(x, y, z)

# %% [markdown]
# ### Exercise
# Create 3 variables, called `name`, `age`, `street`, `town` and give them values. Age should be an `int` type variable.

# %%
...

# %% [markdown]
# ## Variable Types and Type Conversion
# Basic Python types include `int`, `float`, `str`, `bool`. Use `type()` and explicit conversions (`int()`, `float()`, `str()`):

# %%
x = 10
y = 2.5
name = 'Python'

print(type(x), type(y), type(name))

# %%
# Type conversions
x_float = float(x)
y_int = int(y)
print(x, x_float)
print(y, y_int)
# Out:
# 5 5.0
# 10 10

# %%
'one' + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 'one' + 1
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Variable Types and Duck Typing
#
# Python is dynamically typed, which means that variables do not have a fixed type. Instead, the type of a variable is determined at runtime based on the value assigned to it. This is sometimes referred to as **duck typing**.
#
# Duck typing follows the principle:
#
# > "If it walks like a duck and quacks like a duck, then it must be a duck."
#
# In practice, Python cares more about the operations that an object supports rather than its explicit type.
#
# **Example:**

# %%
# Duck typing example:
print(5 + 10)                # integer addition
print(5.1 + 10)            # float addition
print('Hello' + 'Shalom')  # string concatenation

# %% [markdown]
# ## Giving Descriptive Variable Names
#
# When naming variables, it's best practice to choose descriptive, meaningful names that clearly indicate their purpose or content. Descriptive variable names greatly enhance the readability and maintainability of your code.
#
# ### Example of Good vs. Bad Variable Names:
#
# | Poor naming | Descriptive naming |
# |-------------|--------------------|
# | `a`, `b`, `c`| `age`, `salary`, `temperature`|
# | `lst`        | `student_names`|
# | `x`, `y`     | `width`, `height`|
#
# When naming variables with multiple words, use underscores `_` to separate the words (this is known as **snake_case**).

# %% [markdown]
# ## Reserved Names and Existing Function Names
#
# Python has reserved words—known as **keywords**—that are used to define the language’s syntax and structure. You **cannot** use these keywords as variable names.
#
# **Examples of Python keywords:**
# `for`, `while`, `if`, `else`, `elif`, `def`, `return`, `True`, `False`, `None`, `and`, `or`, `import`, etc.
#
# Additionally, while Python allows it, it's considered bad practice to use the names of built-in functions (e.g., `list`, `str`, `print`) as variable names because it overrides the original function.
#
# **Example of what NOT to do:**

# %%
print(round(4.1))

round = 10
print(round)

print(round(10.1))
# Out:
# 4
# 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 6>()
#       3 round = 10
#       4 print(round)
# ----> 6 print(round(10.1))
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ## ---> RESTART KERNEL HERE <---
# To return the `round` function

# %% [markdown]
# #### Converting string to number
# Remember - the computer doesn't "understand", it simply stores and manipulates information.

# %%
x = '041836646'
print(f'{x=}')
y = int(x)
print(f'{y=}')
# Out:
# x='041836646'
# y=41836646

# %%
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# <class 'int'>

# %%
x = '000123'
y = int(x)
print(y)

# %% [markdown]
# ## `print()` function
# We'll be using the `print` function a lot, including in the exercises. It's good to be familiar with how to use it.

# %%
first = "Marcus"
last = "Aurelius"
print("My name is", first, last)
# Out:
# My name is Marcus Aurelius

# %%
 for i in range(3):
    print("My name is", first, last)
# Out:
# My name is Marcus Aurelius
# My name is Marcus Aurelius
# My name is Marcus Aurelius

# %%
print("My name is", first, last, sep = " ") # separator
# Out:
# My name is Marcus Aurelius

# %%
print("My name is", first, last)
print("ABC")
# Out:
# My name is Marcus Aurelius
# ABC

# %%
print("My name is", first, last, end = " ")
print("ABC")
# Out:
# My name is Marcus Aurelius ABC

# %% [markdown]
# ## Numbers and Basic Arithmetic Operations
# Arithmetic operations include addition, subtraction, multiplication, and more:

# %%
result_addition = 8 + 2
result_subtraction = 8 - 2
result_multiplication = 8 * 2

print(f'{result_addition=}', f'{result_subtraction=}', f'{result_multiplication=}', sep = "\n")
# Out:
# result_addition=10
# result_subtraction=6
# result_multiplication=16

# %%
result_division = 8 / 2
result_floor_division = 8 // 2
result_exponentiation = 8 ** 2

print(f'{result_division=}', f'{result_floor_division=}', f'{result_exponentiation=}', sep = "\n")
# Out:
# result_division=4.0
# result_floor_division=4
# result_exponentiation=64

# %%
# Modulus (%)
result_modulus = 8 % 3  # Returns remainder of division
print("Modulus: 8 % 3 =", result_modulus)
# Out:
# Modulus: 8 % 3 = 2

# %% [markdown]
# ### Calculation example, with variable inputs.
# What is the area of triangle?

# %%
a = input()
x = int(a)

print(type(a))
print(type(x))
# Out:
#  6
# <class 'str'>
# <class 'int'>

# %%
print(a * 3)
print(x * 3)
# Out:
# 121212
# 36

# %%
h = int(input())  # height
b = int(input())  # base

triangle = h*b / 2
print("Area of triangle is:", triangle)
# Out:
# Enter height of triangle: 8
# Enter base of triangle: 9
# Area of triangle is: 36.0

# %% [markdown]
# ## Rounding
# Documentation (https://docs.python.org/3.7/library/functions.html?highlight=round#round)
#
# Python provides the round() function as a built-in utility to round off numerical values. This function can be used in two ways:
# - round(number): Rounds the number to the nearest integer.
# - round(number, ndigits): Rounds the number to ndigits decimal places.

# %%
round(2.566)
# Out:
# 3

# %%
print(round(2.566, 0))
print(round(2.566, 2))
# Out:
# 3.0
# 2.57

# %%
round(2.5)
# Out:
# 2

# %%
round(3.5)
# Out:
# 4

# %%
round(4.5)

# %%
.1 + .2

# %% [markdown]
# # Math package (built-in to Python)
# Python comes with a built-in package of math functions. To get access to the functions, we need to `import` the `math` package.

# %%
math.sqrt(16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 math.sqrt(16)
#
# NameError: name 'math' is not defined

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt
sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt as square_root
square_root(99)
# Out:
# 9.9498743710662

# %% [markdown]
# The math package has many built in functions, see: (https://docs.python.org/3/library/math.html)

# %%
print(math.floor(3.99999999))
math.ceil(3.1)
# Out:
# 3
# 4

# %%
math.log(100)

# %% [markdown]
# ## Mathematical constants

# %%
math.log10(math.e)
# Out:
# 0.4342944819032518

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.nan
# Not a Number

# %% [markdown]
# ## Good Coding Practices and Documentation
# Clearly document your code. Follow PEP8 guidelines:

# %%
# Clearly documented and named variables
radius = 5
area_of_circle = math.pi * (radius ** 2)
print(area_of_circle)
